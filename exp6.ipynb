# %% [markdown]
# #Exp:  6
# #Name: Rudransh Sharma
# #PRN:  25070123096
# #AIM:  STUDY OF CONDITIONAL STATEMENTS IN PYTHON

# %%
#6A - CHECK WHETHER A NUMBER IS POSITIVE NEGATIVE OR ZERO
num = int(input("Enter a number:"))
if num > 0:
  print("positive")
elif num < 0:
  print("negative")
else:
  print("Zero")
# Out:
# Enter a number:23
# positive

# %%
#6B - check whether a number is even or odd
num = int(input("Enter a number:"))

if num % 2 == 0:
  print("Even")
else:
  print("Odd")
# Out:
# Enter a number:90
# Even

# %%
#6C - Find the largest of three numbers
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

if (num1 >= num2) and (num1 >= num3):
   largest = num1
elif (num2 >= num1) and (num2 >= num3):
   largest = num2
else:
   largest = num3

print("The largest number is", largest)
# Out:
# Enter first number: 34
# Enter second number: 6
# Enter third number: 99
# The largest number is 99

# %%
#6D(1) - get input from a user and find grade

score = float(input("Enter the student's score: "))

if score >= 90:
  grade = 'A'
elif score >= 75:
  grade = 'B'
elif score >= 50:
  grade = 'C'
elif score >= 40:
  grade = 'D'
else:
  grade = 'Fail'

print("The student's grade is:", grade)
# Out:
# Enter the student's score: 8
# The student's grade is: Fail

# %%
#6D(2) - get input from user for 3 subjects find average grade

# Get input from the user
s1 = float(input("Enter score for subject 1: "))
s2 = float(input("Enter score for subject 2: "))
s3 = float(input("Enter score for subject 3: "))

# Calculate average score
score = (s1 + s2 + s3) / 3

# Determine grade
if score >= 90:
    grade = 'A'
elif score >= 75:
    grade = 'B'
elif score >= 50:
    grade = 'C'
elif score >= 40:
    grade = 'D'
else:
    grade = 'Fail'

# Display results
print("Average Score:", score)
print("Grade:", grade)
# Out:
# Enter score for subject 1: 75
# Enter score for subject 2: 86
# Enter score for subject 3: 30
# Average Score: 63.666666666666664
# Grade: C

# %%
#6E - Check whether a year is leap year
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(year, "is a leap year")
else:
    print(year, "is not a leap year")
# Out:
# Enter a year: 2024
# 2024 is a leap year

# %%
#6F - Incrimante the date
date = input("enter the date in format{dd/mm/yyyy}: ")
dd, mm, yyyy = date.split('/')
dd= int(dd)
mm= int(mm)
yyyy = int(yyyy)
if ( mm==1 or  mm==3 or  mm==5 or  mm==7 or  mm==8 or  mm==10 or  mm==12 ):
 max1=31
elif(mm==4 or mm==6 or mm==9 or mm==11):
 max1=30
elif (yyyy%4==0 and yyyy%100!=0 or yyyy%400==0):
 max1=29
else:
 max1= 28 # Corrected for non-leap February

if (mm<1 or mm>12):
 print("date is invalid")
elif(dd<1 or dd>max1):
 print("date is invalid")
elif(dd==max1 and mm!=12):
 dd=1
 mm=mm+1
 print("date tomorrow is: ", dd,mm,yyyy)
elif(dd==31 and mm==12):
 dd= 1
 mm= 1
 yyyy= yyyy+1
 print(" date tomorrow is: ", dd,mm,yyyy)
else:
 dd = dd+1
 print(" date tomorrow is: ", dd,mm,yyyy)
# Out:
# enter the date in format{dd/mm/yyyy}: 12/12/1212
#  date tomorrow is:  13 12 1212

# %%
#6G - to check a alphabet is vowel or not
ch = input("Enter a character:")



if ch_lower in ('a', 'e', 'i', 'o', 'u'):
  print(ch, "is a vowel")
else:
  print(ch, "is a consonant")
# Out:
# Enter a character:A
# A is a vowel

# %%
#6H - Write a python program to calculate the gross salary of a empolyee
# if basic < 10000: HRA=20%,DA=80%
#if basic <20000:HRA=25%,DA=90%
#otherwise:HRA = 30%,DA= 95%

basic_salary = float(input("Enter the basic salary: "))

if basic_salary < 10000:
  hra_percentage = 0.20
  da_percentage = 0.80
elif basic_salary < 20000:
  hra_percentage = 0.25
  da_percentage = 0.90
else:
  hra_percentage = 0.30
  da_percentage = 0.95

hra = basic_salary * hra_percentage
da = basic_salary * da_percentage
gross_salary = basic_salary + hra + da

print("Basic Salary:", basic_salary)
print("HRA:", hra)
print("DA:", da)
print("Gross Salary:", gross_salary)
# Out:
# Enter the basic salary: 7000
# Basic Salary: 7000.0
# HRA: 1400.0
# DA: 5600.0
# Gross Salary: 14000.0

# %%
'''6I - Write a python program to calculcate income tax based on annual income:
up to ₹2,50,000: No tax
₹2,50,001-₹5,00,000:5%
₹5,00,001-₹10,00,000:20%
above ₹10,00,000:30%
'''

income = float(input("Enter the annual income: "))

if income <= 250000:
    tax = 0
elif income <= 500000:
    tax = (income - 250000) * 0.05
elif income <= 1000000:
    tax = 250000 * 0.05 + (income - 500000) * 0.20
else:
    tax = 250000 * 0.05 + 500000 * 0.20 + (income - 1000000) * 0.30

print("Your income tax is: ₹", tax)
# Out:
# Enter the annual income: 1200000
# Your income tax is: ₹ 172500.0
